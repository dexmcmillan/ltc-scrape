# %% [markdown]
# # Scraping LTC proposals
# *May 10, 2023*

# %% [markdown]
# The goal is to pull all the proposals for LTC homes from [this page](https://www.ontario.ca/page/ontarios-long-term-care-licensing-public-consultation-registry#section-18). Start by importing the modules we'll need.

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# Now we make a request for the HTML from the page, then run it through beautifulsoup.

# %%
r = requests.get("https://www.ontario.ca/page/ontarios-long-term-care-licensing-public-consultation-registry#section-18").content

soup = BeautifulSoup(r, 'html.parser')
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" prefix="og: https://ogp.me/ns#"><head><meta charset="utf-8"/><link href="http://www.ontario.ca/page/ontarios-long-term-care-licensing-public-consultation-registry" rel="canonical"/><meta content="Provide your feedback on proposals for licensing long-term care homes in Ontario." name="description"/><meta content="ontario.ca" property="og:site_name"/><meta content="Ontario’s long-term care licensing public consultation registry" property="og:title"/><meta content="Provide your feedback on proposals for licensing long-term care homes in Ontario." property="og:description"/><meta content="en_CA" property="og:locale"/><meta content="fr_CA" property="og:locale:alternate"/><meta content="summary_large_image" name="twitter:card"/><meta content="@ONgov" name="twitter:site"/><meta content="Provide your feedback on proposals for licensing long-term care homes in Ontario." name="twitter:description"/><meta content="Ontario’s long-term care licensing public consultation registry" name="twitter:title"/><meta content="@ONgov" name="twitter:creator"/><meta content="Drupal 9 (https://www.drupal.org)" name="Generator"/><meta content="width" name="MobileOptimized"/><meta content="true" name="HandheldFriendly"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/><link href="/themes/ontario_2021/assets/apple-touch-icon.png" rel="apple-touch-icon"/><link href="/themes/ontario_2021/favicon.ico" rel="icon" type="image/vnd.microsoft.icon"/><link href="http://www.ontario.ca/page/ontarios-long-term-care-licensing-public-consultation-registry" hreflang="en" rel="alternate"/><link href="http://www.ontario.ca/fr/page/registre-ontarien-des-consultations-publiques-sur-les-permis-de-foyers-de-soins-de-longue-duree" hreflang="fr" rel="alternate"/><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0];var j=d.createElement(s);var dl=l!='dataLayer'?'&l='+l:'';j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl+'';j.async=true;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-KZMGBJD');</script><link href="https://www.googletagmanager.com" rel="preconnect"/><link href="https://www.google-analytics.com" rel="preconnect"/><title>Ontario’s long-term care licensing public consultation registry | ontario.ca</title><link href="/themes/ontario_2021/css/ontario2021-theme.css?rug1oz" media="all" rel="stylesheet"><script src="/core/assets/vendor/jquery/jquery.min.js?v=3.6.3"></script><script src="/core/misc/polyfills/element.matches.js?v=9.5.8"></script><script src="/core/assets/vendor/once/once.min.js?v=1.0.1"></script><svg aria-hidden="true" style="display:none" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><symbol id="ontario-icon-accessibility"><path d="M18.4 11.2l-4.1.2 2.3-2.6c.2-.3.3-.8.2-1.3-.1-.3-.2-.6-.5-.8l-5.4-3.2c-.4-.3-1-.2-1.4.1L6.8 6.1c-.5.5-.6 1.2-.1 1.7.4.5 1.2.5 1.7.1l2-1.8 1.9 1.1-4.2 4.3c-.1.1-.1.2-.2.2-.5.2-1 .4-1.4.7L8 13.9c.5-.2 1-.4 1.5-.4 1.9 0 3.5 1.6 3.5 3.5 0 .6-.1 1.1-.4 1.5l1.5 1.5a5.29 5.29 0 00.9-3c0-1.2-.4-2.4-1.1-3.3l3.3-.3-.2 4.8c-.1.7.4 1.2 1.1 1.3h.1c.6 0 1.1-.5 1.2-1.1l.2-5.9c0-.3-.1-.7-.3-.9-.3-.3-.6-.4-.9-.4zM18 5.5a2 2 0 002-2 2 2 0 00-2-2 2 2 0 00-2 2 2 2 0 002 2zm-5.5 16.1a5.29 5.29 0 01-3 .9C6.5 22.5 4 20 4 17a5.29 5.29 0 01.9-3l1.5 1.5c-.2.5-.4 1-.4 1.5 0 1.9 1.6 3.5 3.5 3.5.6 0 1.1-.1 1.5-.4l1.5 1.5z" fill=""></path></symbol><symbol id="ontario-icon-add-alt"><path d="M12 2C6.48 2 2 6.48 2 12s4.48 10 10 10 10-4.48 10-10S17.52 2 12 2z
19c0 1.1.9 2 2 2h8c1.1 0 2-.9 2-2V7H6v12zM19 4h-3.5l-1-1h-5l-1 1H5v2h14V4z" fill=""></path></symbol><symbol id="ontario-icon-document"><path d="M13 9h5.5L13 3.5V9zM6 2h8l6 6v12a2 2 0 01-2 2H6a2 2 0 01-2-2V4c0-1.1.9-2 2-2zm9 16v-2H6v2h9zm3-4v-2H6v2h12z" fill=""></path></symbol><symbol id="ontario-icon-download"><path d="M5 20h14v-2H5v2zM19 9h-4V3H9v6H5l7 7 7-7z" fill=""></path></symbol><symbol id="ontario-icon-edit"><path d="M3 17.25V21h3.75L17.8 9.94 14.06 6.2 3 17.25zm17.7-10.2c.4-.4.4-1.02 0-1.4L18.37 3.3c-.4-.4-1.02-.4-1.4 0l-1.83 1.83 3.75 3.75 1.83-1.83z" fill=""></path></symbol><symbol id="ontario-icon-export"><path d="M19 12v7H5v-7H3v7c0 1.1.9 2 2 2h14c1.1 0 2-.9 2-2v-7h-2zm-6 .67l2.6-2.58 1.4 1.4-5 5-5-5 1.4-1.4 2.6 2.58V3h2v9.67z" fill=""></path></symbol><symbol id="ontario-icon-facebook-alt"><path d="M5 3h14a2 2 0 012 2v14a2 2 0 01-2 2H5a2 2 0 01-2-2V5a2 2 0 012-2zm13 2h-2.5A3.5 3.5 0 0012 8.5V11h-2v3h2v7h3v-7h3v-3h-3V9a1 1 0 011-1h2V5z" fill=""></path></symbol><symbol id="ontario-icon-facebook"><path d="M17 2v4h-2c-.7 0-1 .8-1 1.5V10h3v4h-3v8h-4v-8H7v-4h3V6a4 4 0 014-4h3z" fill=""></path></symbol><symbol id="ontario-icon-favourite-off"><path d="M12.1 18.55l-.1.1-.1-.1C7.14 14.24 4 11.4 4 8.5 4 6.5 5.5 5 7.5 5c1.54 0 3.04 1 3.57 2.36h1.86C13.46 6 14.96 5 16.5 5c2 0 3.5 1.5 3.5 3.5 0 2.9-3.14 5.74-7.9 10.05zM16.5 3c-1.74 0-3.4.8-4.5 2.08C10.9 3.8 9.24 3 7.5 3 4.42 3 2 5.4 2 8.5c0 3.77 3.4 6.86 8.55 11.53L12 21.35l1.45-1.32C18.6 15.36 22 12.27 22 8.5 22 5.4 19.58 3 16.5 3z" fill=""></path></symbol><symbol id="ontario-icon-favourite-on"><path d="M12 21.35l-1.45-1.32C5.4 15.36 2 12.28 2 8.5 2 5.42 4.42 3 7.5 3A5.99 5.99 0 0112 5.09 5.99 5.99 0 011 ...

# %% [markdown]
# Because each LTC proposal is not nested, we'll need to find the header for each section, and then work our way through the siblings that come after for the information we need.
#
# We'll search for all link tags within h2 tags that have a not null name that is not "archive". Then we go through and get the parent of each of those, so we're left with the all the h2 tags that head up an active proposal.

# %%
all = soup.select("h2 > a[name][id!=archive]")
all = [item.parent for item in all]
all
# Out:
# [<h2><a id="24-013" name="24-013">Neighbourhood Better Living — Project #24-013</a></h2>,
#  <h2><a id="24-015" name="24-015">Project Iris — Project #24-015</a></h2>,
#  <h2><a id="24-021" name="24-021">Delhi Long Term Care Centre — Project #24-021</a></h2>,
#  <h2><a id="24-020" name="24-020">Finlandia Hoivakoti Nursing Home — Project #24-020</a></h2>,
#  <h2><a id="23-064" name="23-064">Mohawks Bay of Quinte — Project #23-064</a></h2>,
#  <h2><a id="23-067" name="23-067">Chateau Park Long Term Care Home — Project #23-067</a></h2>,
#  <h2><a id="24-018" name="24-018">Groves Park Lodge — Project #24-018</a></h2>,
#  <h2><a id="24-017" name="24-017">IOOF Seniors Home — Project #24-017</a></h2>,
#  <h2><a id="24-016" name="24-016">peopleCare - Tillsonburg — Project #24-016</a></h2>,
#  <h2><a id="24-011" name="24-011">Trillium Villa Nursing Home — Project #24-011</a></h2>,
#  <h2><a id="24-003" name="24-003">Extendicare Ottawa #2 — Project #24-003</a></h2>,
#  <h2><a id="24-005" name="24-005">Southbridge Ottawa — Project #24-005</a></h2>,
#  <h2><a id="24-004" name="24-004">Extendicare St. Catharines — Project #24-004</a></h2>,
#  <h2><a id="23-059" name="23-059">Batchewana First Nation Long Term Care Home — Project #23-059</a></h2>,
#  <h2><a id="24-002" name="24-002">Sumac Lodge — Project #24-002</a></h2>,
#  <h2><a id="24-012" name="24-012">Sandfield Place — Project #24-012</a></h2>]

# %% [markdown]
# Now we're going to loop through each element, and get various siblings

# %%
df = []

for item in all:

    next_sib = item.next_sibling
    second_sib = next_sib.next_sibling
    third_sib = second_sib.next_sibling
    fourth_sib = third_sib.next_sibling

    data = {
        "name": [item.text],
        "description": [item.next_sibling.text],
        "closing_date": [item.next_sibling.next_sibling.text],
        "description2": [item.next_sibling.next_sibling.next_sibling.next_sibling.text]
    }

    data = pd.DataFrame(data)
    df.append(data)
        
df = pd.concat(df)

df
# Out:
#                                                 name  \
# 0      Neighbourhood Better Living — Project #24-013
# 0                     Project Iris — Project #24-015
# 0      Delhi Long Term Care Centre — Project #24-021
# 0  Finlandia Hoivakoti Nursing Home — Project #24...
# 0            Mohawks Bay of Quinte — Project #23-064
# 0  Chateau Park Long Term Care Home — Project #23...
# 0                Groves Park Lodge — Project #24-018
# 0                IOOF Seniors Home — Project #24-017
# 0         peopleCare - Tillsonburg — Project #24-016
# 0      Trillium Villa Nursing Home — Project #24-011
# 0            Extendicare Ottawa #2 — Project #24-003
# 0               Southbridge Ottawa — Project #24-005
# 0       Extendicare St. Catharines — Project #24-004
# 0  Batchewana First Nation Long Term Care Home — ...
# 0                      Sumac Lodge — Project #24-002
# 0                  Sandfield Place — Project #24-012
#
#                                          description  \
# 0  The development of a 160-bed long-term care ho...
# 0  The licence transfer of 16 homes from an exist...
# 0  The redevelopment of a 60-bed long-term care h...
# 0  The redevelopment of a 112-bed long-term care ...
# 0  The development of a new 128-bed long-term car...
# 0  The redevelopment of a 59-bed long-term care h...
# 0  The redevelopment of a 100-bed long-term care ...
# 0  The redevelopment of a 162-bed long-term care ...
# 0  The development of a 160-bed long-term care ho...
# 0  The development of a 160-bed long-term care ho...
# 0  The redevelopment of a 240-bed long-term care ...
# 0  The development of a 192-bed long-term care ho...
# 0  The redevelopment of a 152-bed long-term care ...
# 0  The development of a new 96-bed long-term care...
# 0  The redevelopment of a 100-bed long-term care ...
# 0  The development of a 53-bed long-term care hom...
#
#                   closing_date  \
# 0  Closing date: June 17, 2023
# 0   Closing date: June 8, 2023
# 0   Closing date: June 7, 2023
# 0   Closing date: May 27, 2023
# 0   Closing date: May 27, 2023
# 0   Closing date: May 25, 2023
# 0   Closing date: May 22, 2023
# 0   Closing date: May 17, 2023
# 0   Closing date: May 17, 2023
# 0   Closing date: May 17, 2023
# 0   Closing date: May 17, 2023
# 0   Closing date: May 13, 2023
# 0   Closing date: May 12, 2023
# 0   Closing date: May 12, 2023
# 0   Closing date: May 12, 2023
# 0   Closing date: May 10, 2023
#
#                                         description2
# 0  The Ministry of Long-Term Care is reviewing a ...
# 0  The Ministry of Long-Term Care is reviewing a ...
# 0  The Ministry of Long-Term Care is reviewing a ...
# 0  The Ministry of Long-Term Care is reviewing a ...
# 0  The Ministry of Long-Term Care is reviewing a ...
# 0  The Ministry of Long-Term Care is reviewing a ...
# 0  The Ministry of Long-Term Care is reviewing a ...
# 0  The Ministry of Long-Term Care is reviewing a ...
# 0  The Ministry of Long-Term Care is reviewing a ...
# 0  The Ministry of Long-Term Care is reviewing a ...
# 0  The Ministry of Long-Term Care is reviewing a ...
# 0  The Ministry of Long-Term Care is reviewing a ...
# 0  The Ministry of Long-Term Care is reviewing a ...
# 0  The Ministry of Long-Term Care is reviewing a ...
# 0  The Ministry of Long-Term Care is reviewing a ...
# 0  The Ministry of Long-Term Care is reviewing a ...
